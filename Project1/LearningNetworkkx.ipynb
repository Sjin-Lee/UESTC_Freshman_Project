# %%
import warnings
warnings.filterwarnings("ignore")

import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.Graph() # Create a new Graph

# %%
G.add_node(1)
G.add_node(2)
G.add_node(3)

nx.draw(G,with_labels=True)
plt.show()

# %%
G.add_edge(1,2)
G.add_edge(2,3)
nx.draw(G,with_labels=True)
plt.show()

# %%
# When there are many edges ,it will be much more difficult
# so we can use the followings
G2=nx.Graph()
G2.add_nodes_from(list(range(1,5)))
G2.add_edges_from([[1,2],[2,3],[3,4],[4,1]])
nx.draw(G2,with_labels=True)
plt.show()

# %%
# use OPI to create random graphs
randG=nx.erdos_renyi_graph(n=10,p=0.5)
nx.draw(randG)
# n:number of edges 
# p connected possibility
plt.show()

# %%
# Read from data
def readdata(filepath):
    data=[]
    with open(filepath,'r') as f:
        for line in f.readlines():
            data.append(tuple(line.strip().split(' ')))
    return data

# %%
# JassEdges=readdata("./Politicalblogs.txt")

# %%
 JassEdges=readdata("./Jazz.out")

# %%
JassG=nx.Graph()
JassG.add_edges_from(JassEdges)
nx.draw(JassG)
plt.show()

# or use
# JassG2=nx.read_edgeligt('Jass.txt')
